# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Playground-Equip.csv", sep=",")

# %%
dataset.sample(10)
# Out:
#      _id          id                          name     equipment_type  \
# 133  134   535519142              Davis Playground   Play Area 2 to 5
# 245  246   251472869            Arsenal Playground       Swing 4 Bays
# 444  762   405052526  Spring Garden Ave Playground  Play Area 5 to 12
# 340  341   793861937           McKnight Playground  Play Area 5 to 12
# 14    15   991425686             Dunbar Playground       Swing 2 Bays
# 338  339   759278149           McKnight Playground       Swing 2 Bays
# 62    63   463423917     Sheraden Lower Playground              Whirl
# 5      6   788191865          Chartiers Playground       Swing 2 Bays
# 124  125  1747969247             Mellon Playground   Play Area 2 to 5
# 224  225    75953798             Leslie Playground  Play Area 5 to 12
#
#              manufacturer    safety_surface_type ada_accessible  \
# 133             Playworld            SofSurfaces              f
# 245          Little Tykes            SofSurfaces              t
# ...

# %%
# Sort dataframe by neighborhood
df_sorted = df.sort_values(by="neighborhood")

# Count playground equipment in each neighborhood
neighborhood_playground_count = df_sorted["neighborhood"].value_counts()

# Print the results for top 10
top_ten_neighborhoods = neighborhood_playground_count.head(10)
print("Top Ten Neighborhoods and Total Playground Equipment:")
print(top_ten_neighborhoods)
# Out:
# Top Ten Neighborhoods and Total Playground Equipment:
# Squirrel Hill South    32
# East Liberty           26
# Beechview              21
# Allegheny Center       15
# South Side Slopes      14
# Hazelwood              13
# Sheraden               13
# Elliott                11
# Highland Park          10
# Beltzhoover            10
# Name: neighborhood, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.pie(top_ten_neighborhoods, labels=top_ten_neighborhoods.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 10 Neighborhoods with Playground Equipment')
plt.show()

# %% [markdown]
# Using the pie chart visualization, we can easily see that the following neighborhoods have the most playground equipment:
# 1. Squirrel Hill South
# 2. East Liberty
# 3. Beechview
# 4. Allegheny Center
# 5. Southside Slopes
