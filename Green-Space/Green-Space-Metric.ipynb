# %%
import pandas as pd

# %% [markdown]
# First, we will import the pandas library

# %%
dataset = pd.read_csv("Green-Space.csv", sep=",")

# %%
dataset.sample(10)
# Out:
#    Responsibility_Parks or Operations                        Facility  \
# 26                         Operations      Regent Square War Memorial
# 27                         Operations     Reynolds St Planting Circle
# 7                          Operations              East Liberty Strip
# 21                         Operations                Negley Run Strip
# 19                         Operations              Mellon Park Island
# 25                         Operations            Polish Hill Monument
# 8                          Operations                 Edgerton Circle
# 20                         Operations  Monitor St and St Phil Islands
# 1                          Operations            Baum Negley Triangle
# 10                         Operations         Frankstown Triangle 1&2
#
#     Division  Total Acreage  Maintainable Acreage  Shelter  Rec Center  \
# 26       3.0           0.01                   NaN      NaN         0.0
# ...

# %% [markdown]
# Now, we have read in the dataset and sampled it to see the data we are working with.

# %% [markdown]
# To find the neighborhood with the most green space, we will be sorting the dataset by which unique neighborhoods have the most acreage.

# %%
sortedItems= dataset.sort_values(by='Total Acreage', ascending=False, inplace=True)
#sort by acreage

unique_query= dataset['Facility'].unique()
#pull out the unique neighborhoods and display
dataset.head(10)
print(unique_query)
# Out:
# ['East Liberty Strip' 'Frankstown Triangle 1&2' 'Crosstown'
#  'Zulema Passive Area' 'Thomas Blvd Planting Strip' 'Mellon Park Island'
#  'McPherson Blvd Strip' 'Oakland Square' 'Bedford Strip'
#  'Reynolds St Planting Circle' 'Monitor St and St Phil Islands'
#  'Bates St Triangle' 'Baum Negley Triangle' 'Vietnam Island'
#  'Sheraden Monument' 'Beechview Monument' 'Craft Triangle'
#  'Le Roi Rd Island' 'Parkview Islands' 'Harris Triangle'
#  'Brookline Monument' 'Negley-Collins Triangle' 'Highland Ave Plant Strip'
#  'Jail Triangle' 'Windermere Circle 1 & 2' 'Edgerton Circle'
#  'Polish Hill Monument' 'Regent Square War Memorial'
#  'Swisshelm War Memorial' 'Glen Arden Circle & Triangle'
#  'Fort Duquesne Blvd Strip' 'Grant Street Islands' 'Liberty Avenue Island'
#  'Negley Run Strip' nan]

# %% [markdown]
# # Based on this data, the top five neighborhoods with the largest acreage of green space are:
#
# 1. East Liberty Strip
# 2. Frankstown Triangle 1 & 2
# 3. Crosstown
# 4. Zulema Passive Area
# 5. Thomas Blvd Planting Strip
